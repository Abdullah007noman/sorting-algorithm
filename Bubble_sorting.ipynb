# %%
import time
import random
import matplotlib.pyplot as plt
import psutil
import platform

# Bubble Sort Implementation
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Benchmarking Function
def benchmark_bubble_sort(input_sizes):
    times = []
    for size in input_sizes:
        # Generate a random array of the given size
        arr = [random.randint(0, 1000) for _ in range(size)]

        # Start the timer
        start_time = time.time()

        # Perform the bubble sort
        bubble_sort(arr)

        # End the timer
        end_time = time.time()

        # Calculate the time taken and store it
        times.append(end_time - start_time)

    return times

# Function to Plot Runtime vs Input Size
def plot_runtimes(input_sizes, times):
    plt.plot(input_sizes, times, marker='o', linestyle='-', color='g')
    plt.xlabel('Input Size (n)')
    plt.ylabel('Time (seconds)')
    plt.title('Bubble Sort Runtime vs Input Size')
    plt.grid(True)
    plt.show()

# Function to Get System Information
def get_system_info():
    system_info = {
        "CPU": platform.processor(),
        "CPU Cores": psutil.cpu_count(logical=False),
        "Logical CPUs": psutil.cpu_count(logical=True),
        "RAM": f"{round(psutil.virtual_memory().total / (1024 ** 3), 2)} GB",
        "OS": platform.system(),
        "OS Version": platform.version(),
    }
    return system_info

# Main Function
if __name__ == "__main__":
    # Get system information
    system_info = get_system_info()
    print("System Information:")
    for key, value in system_info.items():
        print(f"{key}: {value}")

    # Define input sizes to test
    input_sizes = [5, 10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]

    # Benchmark bubble sort for the given input sizes
    times = benchmark_bubble_sort(input_sizes)

    # Print the results
    print("\nBenchmark Results:")
    print("Input Sizes:", input_sizes)
    print("Times (seconds):", times)

    # Plot the runtime vs input size
    plot_runtimes(input_sizes, times)
# Out:
# System Information:
# CPU: x86_64
# CPU Cores: 1
# Logical CPUs: 2
# RAM: 12.67 GB
# OS: Linux
# OS Version: #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
#
# Benchmark Results:
# Input Sizes: [5, 10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
# Times (seconds): [1.0251998901367188e-05, 1.049041748046875e-05, 2.6941299438476562e-05, 0.00011682510375976562, 0.0005435943603515625, 0.006273746490478516, 0.04066276550292969, 0.18996548652648926, 0.9973926544189453, 5.516176462173462, 12.689574241638184]
